# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

myWeb = nx.DiGraph()
myPages = range(1,6)

connections = [(1,3),(2,1),(2,3),(3,1),(3,2),(3,4),(4,5),(5,1),(5,6)]

myWeb.add_nodes_from(myPages)
myWeb.add_edges_from(connections)

pos = nx.shell_layout(myWeb)
nx.draw(myWeb, pos, arrows=True, with_labels=True)
plt.show()

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

myWeb = nx.DiGraph()
myPages = ["Bangalore", "Hyderabad", "Delhi", "Mumbai", "Kolkata", "Chennai"]

connections = [(myPages[0], myPages[1],1), (myPages[1], myPages[0],2),
              (myPages[2], myPages[3],2), (myPages[3], myPages[4],3),
              (myPages[3], myPages[5],2), (myPages[5], myPages[2],3),
              (myPages[1], myPages[5],2), (myPages[4], myPages[2],3)]

myWeb.add_nodes_from(myPages)
myWeb.add_weighted_edges_from

pos = nx.shell_layout(myWeb)
nx.draw(myWeb, pos, arrows=True, with_labels=True)
plt.show()

# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 5.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 5.5 MB/s eta 0:00:01
# ...

# %%
#!/usr/bin/python
import networkx as nx
import matplotlib.pyplot as plt
myPages = ["Bangalore", "Hyderabad", "Delhi", "Mumbai", "Kolkata", "Chennai"]

connections = [(myPages[0], myPages[1],1), (myPages[1], myPages[0],2),
              (myPages[2], myPages[3],2), (myPages[3], myPages[4],3),
              (myPages[3], myPages[5],2), (myPages[5], myPages[2],3),
              (myPages[1], myPages[5],2), (myPages[4], myPages[2],3)]

G=nx.Graph()
i=1
for name in myPages:
    G.add_node(name,pos=(i,i))
    i+=1
    
for path in connections:
    print(path)
    G.add_edge(path[0], path[1], weight=path[2])

pos=nx.get_node_attributes(G,'pos')
nx.draw(G,pos)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# ('Bangalore', 'Hyderabad', 1)
# ('Hyderabad', 'Bangalore', 2)
# ('Delhi', 'Mumbai', 2)
# ('Mumbai', 'Kolkata', 3)
# ('Mumbai', 'Chennai', 2)
# ('Chennai', 'Delhi', 3)
# ('Hyderabad', 'Chennai', 2)
# ('Kolkata', 'Delhi', 3)
# {('Bangalore', 'Hyderabad'): Text(1.5, 1.5, '2'),
#  ('Hyderabad', 'Chennai'): Text(4.0, 4.0, '2'),
#  ('Delhi', 'Mumbai'): Text(3.5, 3.5, '2'),
#  ('Delhi', 'Chennai'): Text(4.5, 4.5, '3'),
#  ('Delhi', 'Kolkata'): Text(4.0, 4.0, '3'),
#  ('Mumbai', 'Kolkata'): Text(4.5, 4.5, '3'),
#  ('Mumbai', 'Chennai'): Text(5.0, 5.0, '2')}

# %%
import networkx as nx
import matplotlib.pyplot as plt

G=nx.Graph()
i=1
G.add_node(i,pos=(i,i))
G.add_node(2,pos=(2,2))
G.add_node(3,pos=(1,0))
G.add_edge(1,2,weight=0.5)
G.add_edge(1,3,weight=9.8)
pos=nx.get_node_attributes(G,'pos')
nx.draw(G,pos)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {(1, 2): Text(1.5, 1.5, '0.5'), (1, 3): Text(1.0, 0.5, '9.8')}
